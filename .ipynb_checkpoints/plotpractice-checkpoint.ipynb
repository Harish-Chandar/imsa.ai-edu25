# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("diabetes.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
plt.scatter(df["Age"], df["Insulin"])

# %%
plt.scatter(df["Age"], df["BloodPressure"])

# %%
df.Outcome == 1
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 763    False
# 764    False
# 765    False
# 766     True
# 767    False
# Name: Outcome, Length: 768, dtype: bool

# %%
filtered = df[df["Age"] > 70].filter(["Pregnancies", "Glucose", "Age", "Outcome"])
filtered
# Out:
#      Pregnancies  Glucose  Age  Outcome
# 453            2      119   72        0
# 459            9      134   81        0

# %%
df[:200]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 195            5      158             84             41      210  39.4
# 196            1      105             58              0        0  24.3
# 197            3      107             62             13       48  22.9
# 198            4      109             64             44       99  34.8
# 199            4      148             60             27      318  30.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
sortedx = df.sort_values(by="SkinThickness")
sortedx
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 12            10      139             80              0        0  27.1
# 739            1      102             74              0        0  39.5
# 743            9      140             94              0        0  32.7
# 437            5      147             75              0        0  29.9
# 766            1      126             60              0        0  30.1
# ..           ...      ...            ...            ...      ...   ...
# 86            13      106             72             54        0  36.6
# 120            0      162             76             56      100  53.2
# 57             0      100             88             60      110  46.8
# 445            0      180             78             63       14  59.4
# 579            2      197             70             99        0  34.7
#
#      DiabetesPedigreeFunction  Age  Outcome
# 12                      1.441   57        0
# ...

# %%
df2 = df.Outcome.apply(lambda x : x-1)
df2.head
# Out:
# <bound method NDFrame.head of 0      0
# 1     -1
# 2      0
# 3     -1
# 4      0
#       ..
# 763   -1
# 764   -1
# 765   -1
# 766    0
# 767   -1
# Name: Outcome, Length: 768, dtype: int64>

# %%
plt.scatter(df['Age'],df['BMI'])

# %%
plt.scatter(df["SkinThickness"], df["BMI"])

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.imshow([df["Glucose"], df["Age"]], cmap='viridis')
plt.colorbar()  # Add a colorbar to the plot
plt.show()

# %%
plt.boxplot(df['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f4c78a70e60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f4c78ad3140>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f4c78a71fd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f4c78ad3aa0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f4c78ad2ae0>],
#  'means': []}
